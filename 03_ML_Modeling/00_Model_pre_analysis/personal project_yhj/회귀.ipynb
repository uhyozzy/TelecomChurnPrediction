# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/multi_finalproject/blob/hyojin/personal%20project/%ED%9A%8C%EA%B7%80.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Base**

# %%
# modules
import numpy as np
import pandas as pd

# Preprocessing
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split

# Visualization
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import plotly.express as px

# %% [markdown]
# # **0. 데이터 불러오기**

# %%
# 파일읽기, 불러오기
df = pd.read_excel('/content/Data_Set.xlsx')
df
# Out:
#       Age  Age Group  Number of Dependents  Tenure in Months  Online Security  \
# 0      78         70                     0                 1                0
# 1      74         70                     1                 8                0
# 2      71         70                     3                18                0
# 3      78         70                     1                25                0
# 4      80         80                     1                37                0
# ...   ...        ...                   ...               ...              ...
# 7038   30         30                     0                72                0
# 7039   38         30                     2                24                1
# 7040   30         30                     2                72                0
# 7041   32         30                     2                11                1
# 7042   44         40                     0                66                1
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     7043 non-null   int64
#  1   Age Group               7043 non-null   int64
#  2   Number of Dependents    7043 non-null   int64
#  3   Tenure in Months        7043 non-null   int64
#  4   Online Security         7043 non-null   int64
#  5   Online Backup           7043 non-null   int64
#  6   Device Protection Plan  7043 non-null   int64
#  7   Premium Tech Support    7043 non-null   int64
#  8   Tech Use                7043 non-null   int64
#  9   Combined Product        7043 non-null   int64
#  10  Membership              7043 non-null   object
#  11  Contract                7043 non-null   object
#  12  Churn Score             7043 non-null   int64
# dtypes: int64(11), object(2)
# memory usage: 715.4+ KB

# %% [markdown]
# ## **0-1.수치형 데이터 통계확인**

# %%
df.describe()
# Out:
#                Age    Age Group  Number of Dependents  Tenure in Months  \
# count  7043.000000  7043.000000           7043.000000       7043.000000
# mean     46.509726    42.080080              0.468692         32.386767
# std      16.750352    16.824042              0.962802         24.542061
# min      19.000000    10.000000              0.000000          1.000000
# 25%      32.000000    30.000000              0.000000          9.000000
# 50%      46.000000    40.000000              0.000000         29.000000
# 75%      60.000000    60.000000              0.000000         55.000000
# max      80.000000    80.000000              9.000000         72.000000
#
#        Online Security  Online Backup  Device Protection Plan  \
# count      7043.000000    7043.000000             7043.000000
# mean          0.286668       0.344881                0.343888
# std           0.452237       0.475363                0.475038
# min           0.000000       0.000000                0.000000
# ...

# %% [markdown]
# ## **0-2.범주형 데이터 통계확인**

# %%
df.describe(include = np.object_)
# Out:
#        Membership        Contract
# count        7043            7043
# unique          6               3
# top          None  Month-to-Month
# freq         3877            3610

# %% [markdown]
# ## **0-3. Label 데이터 통계확인**
# - 결론
#   - Churn Score : ~40 안정 그룹
#   - Churn Score : 40~60 잠재적 이탈 그룹
#   - Churn Score : 60~90 고위험 이탈 그룹
#   - Churn Score : 90~  이탈 그룹

# %%
# churn group 파일읽기, 불러오기
churn_df = pd.read_excel('/content/churn_group.xlsx')
churn_df
# Out:
#       Churn Value  Churn Score  Churn Score Group
# 0               1           91                 90
# 1               1           69                 60
# 2               1           81                 80
# 3               1           88                 80
# 4               1           67                 60
# ...           ...          ...                ...
# 7038            0           45                 40
# 7039            0           59                 50
# 7040            0           71                 70
# 7041            0           59                 50
# 7042            0           38                 30
#
# [7043 rows x 3 columns]

# %% [markdown]
# **이탈자(Churn Value=1)의 분포**
# - Churn Score가 60이상이면 이탈자가 존재

# %%
filter = churn_df[churn_df['Churn Value'] == 1] # 'Churn Value'가 1인 데이터만 필터링

count_data = filter.groupby(['Churn Score Group']).size().reset_index(name='Churn Value_Count') # 'Churn Score Group'별로 'Churn Value'의 갯수를 계산

fig = px.bar(count_data, x='Churn Score Group', y='Churn Value_Count', color='Churn Score Group',
             width=600, height=400) # 그래프 생성
fig.update_traces(showlegend=False) # 범례 생략

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **비 이탈자(Churn Value=0)의 분포**
# - 이탈자와의 교집합: Churn Score가 60~80인 경우
# - Churn Score가 90인 경우: 비이탈자 존재X

# %%
filter = churn_df[churn_df['Churn Value'] == 0] # 'Churn Value'가 1인 데이터만 필터링

count_data = filter.groupby(['Churn Score Group']).size().reset_index(name='Churn Value_Count') # 'Churn Score Group'별로 'Churn Value'의 갯수를 계산

fig = px.bar(count_data, x='Churn Score Group', y='Churn Value_Count', color='Churn Score Group',
             width=600, height=400) # 그래프 생성
fig.update_traces(showlegend=False) # 범례 생략

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# # **1. 데이터 전처리**

# %% [markdown]
# ## **1-1. 데이터타입 조정**
# - Membership 카테고리 컬럼을 5단계로 나누어 변경한다.
#   - Offer A: 1, Offer B: 2, Offer C: 3, Offer D: 4, Offer E: 5, None: 0
#   - 단, 0은 멤버쉽이 아님을 의미하며 'A→E'는 멤버쉽 정도의 '낮음→높음'을 의미한다.
# - Contract 컬럼의 계약 유형도 개월수 데이터로 변경해준다
#   - Month-to-month : 1, One year : 12, Two year : 24

# %%
# Offer A: 1, Offer B: 2, Offer C: 3, Offer D: 4, Offer E: 5, None: 0 로 변경

df.loc[df["Membership"]=='Offer A', "Membership"] = 1
df.loc[df["Membership"]=='Offer B', "Membership"] = 2
df.loc[df["Membership"]=='Offer C', "Membership"] = 3
df.loc[df["Membership"]=='Offer D', "Membership"] = 4
df.loc[df["Membership"]=='Offer E', "Membership"] = 5
df.loc[df["Membership"]=='None', "Membership"] = 0

df["Membership"] = df["Membership"].astype('int64')

# %%
# Month-to-month:1, One year:12, Two year:24 로 변경
df.loc[df["Contract"]=='Month-to-Month', "Contract"] = 1
df.loc[df["Contract"]=='One Year', "Contract"] = 12
df.loc[df["Contract"]=='Two Year', "Contract"] = 24

df["Contract"] = df["Contract"].astype('int64')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Age                     7043 non-null   int64
#  1   Age Group               7043 non-null   int64
#  2   Number of Dependents    7043 non-null   int64
#  3   Tenure in Months        7043 non-null   int64
#  4   Online Security         7043 non-null   int64
#  5   Online Backup           7043 non-null   int64
#  6   Device Protection Plan  7043 non-null   int64
#  7   Premium Tech Support    7043 non-null   int64
#  8   Tech Use                7043 non-null   int64
#  9   Combined Product        7043 non-null   int64
#  10  Membership              7043 non-null   int64
#  11  Contract                7043 non-null   int64
#  12  Churn Score             7043 non-null   int64
# dtypes: int64(13)
# memory usage: 715.4 KB

# %% [markdown]
# **필요 없는 열 제거**

# %%
# 상관관계 분석에 필요없는 컬럼제거 후 새로운 데이터 프레임 생성
data = df.drop(['Age', 'Online Security', 'Online Backup',
                'Device Protection Plan', 'Premium Tech Support'], axis=1)
data
# Out:
#       Age Group  Number of Dependents  Tenure in Months  Tech Use  \
# 0            70                     0                 1         1
# 1            70                     1                 8         1
# 2            70                     3                18         0
# 3            70                     1                25         2
# 4            80                     1                37         0
# ...         ...                   ...               ...       ...
# 7038         30                     0                72         0
# 7039         30                     2                24         3
# 7040         30                     2                72         2
# 7041         30                     2                11         1
# 7042         40                     0                66         4
#
#       Combined Product  Membership  Contract  Churn Score
# 0                    0           0         1           91
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Age Group             7043 non-null   int64
#  1   Number of Dependents  7043 non-null   int64
#  2   Tenure in Months      7043 non-null   int64
#  3   Tech Use              7043 non-null   int64
#  4   Combined Product      7043 non-null   int64
#  5   Membership            7043 non-null   int64
#  6   Contract              7043 non-null   int64
#  7   Churn Score           7043 non-null   int64
# dtypes: int64(8)
# memory usage: 440.3 KB

# %%
data.describe()
# Out:
#          Age Group  Number of Dependents  Tenure in Months     Tech Use  \
# count  7043.000000           7043.000000       7043.000000  7043.000000
# mean     42.080080              0.468692         32.386767     1.265796
# std      16.824042              0.962802         24.542061     1.287126
# min      10.000000              0.000000          1.000000     0.000000
# 25%      30.000000              0.000000          9.000000     0.000000
# 50%      40.000000              0.000000         29.000000     1.000000
# 75%      60.000000              0.000000         55.000000     2.000000
# max      80.000000              9.000000         72.000000     4.000000
#
#        Combined Product   Membership     Contract  Churn Score
# count       7043.000000  7043.000000  7043.000000  7043.000000
# mean           0.903166     1.397984     9.570070    58.505040
# std            0.295752     1.828467     9.727735    21.170031
# min            0.000000     0.000000     1.000000     5.000000
# ...

# %% [markdown]
# ## **1-2. 가중치 추가**

# %% [markdown]
# **가중치 추가 전 상관관계**

# %%
# 'New Churn Score'와 다른 열들 간의 상관계수 계산
correlation0 = data.corr()['Churn Score']
correlation0
# Out:
# Age Group               0.079598
# Number of Dependents   -0.160743
# Tenure in Months       -0.224982
# Tech Use               -0.117083
# Combined Product        0.024664
# Membership              0.082647
# Contract               -0.289029
# Churn Score             1.000000
# Name: Churn Score, dtype: float64

# %% [markdown]
# -  EDA 결과, 각 features 별 Churn Score와의 상관관계는 다음과 같았다.
#   - Number of Dependents    : 부양가족이 많을수록 이탈 확률이 낮음
#   - Tenure in Months        : 이용개월수가 많을수록 이탈 확률이 낮음
#   - Tech Use                : 기술 서비스 이용 횟수가 많을수록 이탈 확률이 낮음
#   - Contract	           : 계약의 규모가 높을수록 이탈 확률이 낮음
#
# - 임의로 추가 및 보정할 컬럼
#   - Age Group               : 나이가 많을 수록 이탈 확률이 낮음
#   - Combined Product        : 결합 서비스를 이용할수록 이탈 확률이 낮음
#   - Membership              : 멤버십 단계가 높을수록 이탈 확률이 낮음

# %%
# 상관도를 목적에 맞게 보정할 수 있도록 Churn Score의 표준편차(21)를 곱함

# 기본적으로 'Churn Score' 값을 복사
data['New Churn Score'] = data['Churn Score']

# 1단계: Age Group 값이 20 또는 30인 경우 'Churn Score' 값에 1 더하기
data.loc[(data['Age Group'] == 20) | (data['Age Group'] == 30), 'New Churn Score'] += 21

# 2단계: Combined Product 값이 1인 경우 'Churn Score' 값에 1 빼기
data.loc[data['Combined Product'] == 1, 'New Churn Score'] -= 21

# 3단계: Membership 값이 1인 경우 'Churn Score' 값에 1 빼기
data.loc[data['Membership'] == 1, 'New Churn Score'] -= 5
data.loc[data['Membership'] == 2, 'New Churn Score'] -= 10
data.loc[data['Membership'] == 3, 'New Churn Score'] -= 15
data.loc[data['Membership'] == 4, 'New Churn Score'] -= 20
data.loc[data['Membership'] == 5, 'New Churn Score'] -= 21

# %%
data
# Out:
#       Age Group  Number of Dependents  Tenure in Months  Tech Use  \
# 0            70                     0                 1         1
# 1            70                     1                 8         1
# 2            70                     3                18         0
# 3            70                     1                25         2
# 4            80                     1                37         0
# ...         ...                   ...               ...       ...
# 7038         30                     0                72         0
# 7039         30                     2                24         3
# 7040         30                     2                72         2
# 7041         30                     2                11         1
# 7042         40                     0                66         4
#
#       Combined Product  Membership  Contract  Churn Score  New Churn Score
# 0                    0           0         1           91               91
# ...

# %% [markdown]
# **가중치 추가 후 상관관계 분석**

# %%
# 'New Churn Score'와 다른 열들 간의 상관계수 계산
correlation = data.corr()['New Churn Score']
correlation
# Out:
# Age Group              -0.239583
# Number of Dependents   -0.105083
# Tenure in Months       -0.100184
# Tech Use               -0.019274
# Combined Product       -0.229998
# Membership             -0.259184
# Contract               -0.190414
# Churn Score             0.812746
# New Churn Score         1.000000
# Name: New Churn Score, dtype: float64

# %%
# 양의 상관계수를 갖는 행 이름 출력
positive_correlation = correlation[correlation > 0].index.tolist()
print("양의 상관계수를 갖는 행 이름:\n", positive_correlation, '\n')

# 음의 상관계수를 갖는 행 이름 출력
negative_correlation = correlation[correlation < 0].index.tolist()
print("음의 상관계수를 갖는 행 이름:\n", negative_correlation)
# Out:
# 양의 상관계수를 갖는 행 이름:
#  ['Churn Score', 'New Churn Score']
#
# 음의 상관계수를 갖는 행 이름:
#  ['Age Group', 'Number of Dependents', 'Tenure in Months', 'Tech Use', 'Combined Product', 'Membership', 'Contract']

# %% [markdown]
# **모델링용 최종 데이터셋 생성**

# %%
# 모델링에 필요없는 컬럼제거 후 새로운 데이터 프레임 생성
data_set = data.drop(['Churn Score'], axis=1)
data_set
# Out:
#       Age Group  Number of Dependents  Tenure in Months  Tech Use  \
# 0            70                     0                 1         1
# 1            70                     1                 8         1
# 2            70                     3                18         0
# 3            70                     1                25         2
# 4            80                     1                37         0
# ...         ...                   ...               ...       ...
# 7038         30                     0                72         0
# 7039         30                     2                24         3
# 7040         30                     2                72         2
# 7041         30                     2                11         1
# 7042         40                     0                66         4
#
#       Combined Product  Membership  Contract  New Churn Score
# 0                    0           0         1               91
# ...

# %%
data_set.describe()
# Out:
#          Age Group  Number of Dependents  Tenure in Months     Tech Use  \
# count  7043.000000           7043.000000       7043.000000  7043.000000
# mean     42.080080              0.468692         32.386767     1.265796
# std      16.824042              0.962802         24.542061     1.287126
# min      10.000000              0.000000          1.000000     0.000000
# 25%      30.000000              0.000000          9.000000     0.000000
# 50%      40.000000              0.000000         29.000000     1.000000
# 75%      60.000000              0.000000         55.000000     2.000000
# max      80.000000              9.000000         72.000000     4.000000
#
#        Combined Product   Membership     Contract  New Churn Score
# count       7043.000000  7043.000000  7043.000000      7043.000000
# mean           0.903166     1.397984     9.570070        40.579299
# std            0.295752     1.828467     9.727735        24.558662
# ...

# %% [markdown]
# ## **1-3. Encoding (MinMaxScaler)**

# %% [markdown]
# ### **1-3-1. Features Encoding**

# %%
from sklearn.preprocessing import MinMaxScaler

num_cols = ['Age Group', 'Number of Dependents', 'Tenure in Months',
            'Tech Use', 'Combined Product',
            'Membership', 'Contract']

scaler = MinMaxScaler()
data_set[num_cols] = scaler.fit_transform(data_set[num_cols])

# %%
data_set.head()
# Out:
#    Age Group  Number of Dependents  Tenure in Months  Tech Use  \
# 0   0.857143              0.000000          0.000000      0.25
# 1   0.857143              0.111111          0.098592      0.25
# 2   0.857143              0.333333          0.239437      0.00
# 3   0.857143              0.111111          0.338028      0.50
# 4   1.000000              0.111111          0.507042      0.00
#
#    Combined Product  Membership  Contract  New Churn Score
# 0               0.0         0.0       0.0               91
# 1               1.0         1.0       0.0               27
# 2               1.0         0.8       0.0               40
# 3               1.0         0.6       0.0               52
# 4               1.0         0.6       0.0               31

# %% [markdown]
# ## **1-4. VIF계산 - 다중공선성 점검**
# - 다중공선성을 야기하는 features는 없는 것으로 판단됨

# %%
from statsmodels.stats.outliers_influence import variance_inflation_factor

vif = pd.DataFrame()
vif['VIF Factor'] = [variance_inflation_factor(
    data_set[num_cols].values, i) for i in range(data_set[num_cols].shape[1])]
vif['features'] = data_set[num_cols].columns
print(vif)
# Out:
#    VIF Factor              features
# 0    3.714726             Age Group
# 1    1.257014  Number of Dependents
# 2    5.552524      Tenure in Months
# 3    2.555522              Tech Use
# 4    4.903815      Combined Product
# 5    1.615128            Membership
# 6    3.075057              Contract

# %% [markdown]
# ## **1-5. 학습/검증 데이터 생성**

# %%
from sklearn.model_selection import train_test_split

# Label 데이터셋 추출
label_column = 'New Churn Score'
y = data_set[label_column]

# Feature 데이터셋 추출(Label을 제외한 모든 컬럼)
x = data_set.drop(columns=[label_column])

# Feature 데이터셋과 Label 데이터셋을 train과 test 세트로 분할
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# **Label Encoding**

# %%
from sklearn.preprocessing import LabelEncoder

# LabelEncoder 객체 생성
label_encoder = LabelEncoder()

# 레이블 데이터에 대한 인코딩 수행
y_train_encoded = label_encoder.fit_transform(y_train)
y_test_encoded = label_encoder.transform(y_test)

# %%
min_value = np.min(y_train_encoded)
max_value = np.max(y_train_encoded)

print(f"최소값: {min_value}")
print(f"최대값: {max_value}")
# Out:
# 최소값: 0
# 최대값: 129

# %% [markdown]
# # **2. 모델링**

# %% [markdown]
# ## **2-1. SVM**

# %%
from sklearn.svm import SVC
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score


model=SVC() # SVM 모델 초기화
model.fit(x_train,y_train) # 모델 학습
y_pred = model.predict(x_test) # 테스트 데이터 예측
accuracy = accuracy_score(y_test, y_pred) # 정확도 계산

# %%
accuracy
# Out:
# 0.0191625266146203

# %% [markdown]
# ## **2-2. 앙상블**

# %% [markdown]
# ### **2-2-1. XGBoost(XGBRegressor)**

# %%
from xgboost import XGBRegressor
from sklearn.metrics import mean_squared_error

# XGBoost 회귀 모델 학습
xgb = XGBRegressor()
xgb.fit(x_train, y_train_encoded)  # x_train과 y_train_encoded는 회귀 분석을 위한 입력 데이터와 타겟 데이터입니다.

# 학습 데이터에 대한 예측
y_pred = xgb.predict(x_train)

# MSE를 사용하여 모델 평가
mse = mean_squared_error(y_train_encoded, y_pred)
print("MSE: {:.4f}".format(mse))
# Out:
# MSE: 234.1243

# %% [markdown]
# ### **2-2-2. LightGBM**

# %%
# LightGBM 데이터셋 생성
train_data = lgb.Dataset(x_train, label=y_train)

# LightGBM 회귀 모델 설정
params = {
    'objective': 'regression',  # 회귀 모델
    'metric': 'mse',  # 평가 지표로 MSE 사용
    'boosting_type': 'gbdt',  # Gradient Boosting Decision Tree
    'num_leaves': 31,  # 나무의 최대 잎 노드 수
    'learning_rate': 0.05,  # 학습률
    'feature_fraction': 0.9,  # 각 트리마다 사용할 피처 비율
    'bagging_fraction': 0.8,  # 각 트리마다 사용할 데이터 비율
    'bagging_freq': 5,  # 데이터 샘플링 빈도
    'verbose': 0  # 학습 과정 로그 출력 여부
}

# 모델 학습
num_round = 100  # 학습 라운드 수
bst = lgb.train(params, train_data, num_round)

# 테스트 데이터에 대한 예측
y_pred = bst.predict(x_test, num_iteration=bst.best_iteration)

# MSE를 사용하여 모델 평가
mse = mean_squared_error(y_test, y_pred)
print("MSE: {:.4f}".format(mse))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-29-8a6e8dd455f1> in <cell line: 2>()
#       1 # LightGBM 데이터셋 생성
# ----> 2 train_data = lgb.Dataset(x_train, label=y_train)
#       3
#       4 # LightGBM 회귀 모델 설정
#       5 params = {
#
# NameError: name 'lgb' is not defined

# %% [markdown]
# ### **2-2-3. RandomForest(RandomForestRegressor)**

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error

# RandomForest 회귀 모델 학습
ranfo = RandomForestRegressor(n_estimators=1000, random_state=0)
ranfo.fit(x_train, y_train_encoded)  # x_train과 y_train_encoded는 회귀 분석을 위한 입력 데이터와 타겟 데이터입니다.

# 학습 데이터에 대한 예측
y_pred = ranfo.predict(x_train)

# MSE를 사용하여 모델 평가
mse = mean_squared_error(y_train_encoded, y_pred)
print("MSE: {:.4f}".format(mse))
# Out:
# MSE: 145.8376

# %% [markdown]
# # **3. 모델 평가**
