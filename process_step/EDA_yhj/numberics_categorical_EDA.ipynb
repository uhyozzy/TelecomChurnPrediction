# %% [markdown]
# <a href="https://colab.research.google.com/github/uhyozzy/multi_finalproject/blob/master/EDA/numberics_categorical_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install plotly
# !pip install jupyter-dash #plotly로 만든 그래프를 쥬피터 노트북에 출력하는 패키지

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import folium
import plotly.express as px

# %% [markdown]
# # **Numberics Data**

# %% [markdown]
# ## **파일준비**
# - demograpics
# - services

# %%
# demograpics 파일읽기, 불러오기
demo_df = pd.read_excel('/content/Telco_customer_churn_demographics.xlsx')
demo_df
# Out:
#       Gender  Age  Under 30  Senior Citizen  Married  Dependents  \
# 0          0   78         0               1        0           0
# 1          1   74         0               1        1           1
# 2          0   71         0               1        0           1
# 3          1   78         0               1        1           1
# 4          1   80         0               1        1           1
# ...      ...  ...       ...             ...      ...         ...
# 7038       1   30         0               0        0           0
# 7039       0   38         0               0        1           1
# 7040       1   30         0               0        1           1
# 7041       1   32         0               0        1           1
# 7042       0   44         0               0        0           0
#
#       Number of Dependents  Satisfaction Score  Churn Value  Churn Score  CLTV
# 0                        0                   3            1           91  5433
# 1                        1                   3            1           69  5302
# 2                        3                   2            1           81  3179
# 3                        1                   2            1           88  5337
# 4                        1                   2            1           67  2793
# ...                    ...                 ...          ...          ...   ...
# 7038                     0                   5            0           45  5306
# 7039                     2                   3            0           59  2140
# 7040                     2                   4            0           71  5560
# 7041                     2                   4            0           59  2793
# 7042                     0                   4            0           38  5097
#
# [7043 rows x 11 columns]

# %%
demo_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Gender                7043 non-null   int64
#  1   Age                   7043 non-null   int64
#  2   Under 30              7043 non-null   int64
#  3   Senior Citizen        7043 non-null   int64
#  4   Married               7043 non-null   int64
#  5   Dependents            7043 non-null   int64
#  6   Number of Dependents  7043 non-null   int64
#  7   Satisfaction Score    7043 non-null   int64
#  8   Churn Value           7043 non-null   int64
#  9   Churn Score           7043 non-null   int64
#  10  CLTV                  7043 non-null   int64
# dtypes: int64(11)
# memory usage: 605.4 KB

# %%
# services 파일읽기, 불러오기
serv_df = pd.read_excel('/content/Telco_customer_churn_services.xlsx')
serv_df
# Out:
#       Referred a Friend  Number of Referrals  Tenure in Months  Phone Service  \
# 0                     0                    0                 1              0
# 1                     1                    1                 8              1
# 2                     0                    0                18              1
# 3                     1                    1                25              1
# 4                     1                    1                37              1
# ...                 ...                  ...               ...            ...
# 7038                  0                    0                72              1
# 7039                  1                    1                24              1
# 7040                  1                    4                72              1
# 7041                  1                    1                11              0
# 7042                  0                    0                66              1
#
#       Avg Monthly Long Distance Charges  Multiple Lines  Internet Service  \
# 0                                  0.00               0                 1
# 1                                 48.85               1                 1
# 2                                 11.33               1                 1
# 3                                 19.76               0                 1
# 4                                  6.33               1                 1
# ...                                 ...             ...               ...
# 7038                              22.77               0                 0
# 7039                              36.05               1                 1
# 7040                              29.66               1                 1
# 7041                               0.00               0                 1
# 7042                              30.96               0                 1
#
#       Avg Monthly GB Download  Online Security  Online Backup  ...  \
# 0                           8                0              0  ...
# 1                          17                0              1  ...
# 2                          52                0              0  ...
# 3                          12                0              1  ...
# 4                          14                0              0  ...
# ...                       ...              ...            ...  ...
# 7038                        0                0              0  ...
# 7039                       24                1              0  ...
# 7040                       59                0              1  ...
# 7041                       17                1              0  ...
# 7042                       11                1              0  ...
#
#       Monthly Charge  Total Charges  Total Refunds  Total Extra Data Charges  \
# 0              39.65          39.65           0.00                        20
# 1              80.65         633.30           0.00                         0
# 2              95.45        1752.55          45.61                         0
# 3              98.50        2514.50          13.43                         0
# 4              76.50        2868.15           0.00                         0
# ...              ...            ...            ...                       ...
# 7038           21.15        1419.40          19.31                         0
# 7039           84.80        1990.50          48.23                         0
# 7040          103.20        7362.90          45.38                         0
# 7041           29.60         346.45          27.24                         0
# 7042          105.65        6844.50           0.00                         0
#
#       Total Long Distance Charges  Total Revenue  Satisfaction Score  \
# 0                            0.00          59.65                   3
# 1                          390.80        1024.10                   3
# 2                          203.94        1910.88                   2
# 3                          494.00        2995.07                   2
# 4                          234.21        3102.36                   2
# ...                           ...            ...                 ...
# 7038                      1639.44        3039.53                   5
# 7039                       865.20        2807.47                   3
# 7040                      2135.52        9453.04                   4
# 7041                         0.00         319.21                   4
# 7042                      2043.36        8887.86                   4
#
#       Churn Value  Churn Score  CLTV
# 0               1           91  5433
# 1               1           69  5302
# 2               1           81  3179
# 3               1           88  5337
# 4               1           67  2793
# ...           ...          ...   ...
# 7038            0           45  5306
# 7039            0           59  2140
# 7040            0           71  5560
# 7041            0           59  2793
# 7042            0           38  5097
#
# [7043 rows x 27 columns]

# %%
serv_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 27 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Referred a Friend                  7043 non-null   int64
#  1   Number of Referrals                7043 non-null   int64
#  2   Tenure in Months                   7043 non-null   int64
#  3   Phone Service                      7043 non-null   int64
#  4   Avg Monthly Long Distance Charges  7043 non-null   float64
#  5   Multiple Lines                     7043 non-null   int64
#  6   Internet Service                   7043 non-null   int64
#  7   Avg Monthly GB Download            7043 non-null   int64
#  8   Online Security                    7043 non-null   int64
#  9   Online Backup                      7043 non-null   int64
#  10  Device Protection Plan             7043 non-null   int64
#  11  Premium Tech Support               7043 non-null   int64
#  12  Streaming TV                       7043 non-null   int64
#  13  Streaming Movies                   7043 non-null   int64
#  14  Streaming Music                    7043 non-null   int64
#  15  Unlimited Data                     7043 non-null   int64
#  16  Paperless Billing                  7043 non-null   int64
#  17  Monthly Charge                     7043 non-null   float64
#  18  Total Charges                      7043 non-null   float64
#  19  Total Refunds                      7043 non-null   float64
#  20  Total Extra Data Charges           7043 non-null   int64
#  21  Total Long Distance Charges        7043 non-null   float64
#  22  Total Revenue                      7043 non-null   float64
#  23  Satisfaction Score                 7043 non-null   int64
#  24  Churn Value                        7043 non-null   int64
#  25  Churn Score                        7043 non-null   int64
#  26  CLTV                               7043 non-null   int64
# dtypes: float64(6), int64(21)
# memory usage: 1.5 MB

# %% [markdown]
# ## **상관관계 분석**

# %% [markdown]
# **demograpics와 status**

# %%
demo_corr=demo_df.corr()
demo_corr
# Out:
#                         Gender       Age  Under 30  Senior Citizen   Married  \
# Gender                1.000000 -0.002186  0.002962        0.001874  0.001808
# Age                  -0.002186  1.000000 -0.672651        0.681507 -0.003666
# Under 30              0.002962 -0.672651  1.000000       -0.219216  0.015140
# Senior Citizen        0.001874  0.681507 -0.219216        1.000000  0.016479
# Married               0.001808 -0.003666  0.015140        0.016479  1.000000
# Dependents           -0.005229 -0.125450  0.041651       -0.174396  0.363430
# Number of Dependents -0.005840 -0.119000  0.036340       -0.168152  0.324205
# Satisfaction Score    0.003948 -0.085170  0.041993       -0.116601  0.077743
# Churn Value           0.008612  0.115760 -0.054604        0.150889 -0.150448
# Churn Score          -0.000638  0.083919 -0.043948        0.101947 -0.111704
# CLTV                  0.006851 -0.001826 -0.008363       -0.003167  0.137859
#
#                       Dependents  Number of Dependents  Satisfaction Score  \
# Gender                 -0.005229             -0.005840            0.003948
# Age                    -0.125450             -0.119000           -0.085170
# Under 30                0.041651              0.036340            0.041993
# Senior Citizen         -0.174396             -0.168152           -0.116601
# Married                 0.363430              0.324205            0.077743
# Dependents              1.000000              0.888234            0.168359
# Number of Dependents    0.888234              1.000000            0.152873
# Satisfaction Score      0.168359              0.152873            1.000000
# Churn Value            -0.248542             -0.218780           -0.754649
# Churn Score            -0.173695             -0.160743           -0.495144
# CLTV                    0.058222              0.049611            0.075811
#
#                       Churn Value  Churn Score      CLTV
# Gender                   0.008612    -0.000638  0.006851
# Age                      0.115760     0.083919 -0.001826
# Under 30                -0.054604    -0.043948 -0.008363
# Senior Citizen           0.150889     0.101947 -0.003167
# Married                 -0.150448    -0.111704  0.137859
# Dependents              -0.248542    -0.173695  0.058222
# Number of Dependents    -0.218780    -0.160743  0.049611
# Satisfaction Score      -0.754649    -0.495144  0.075811
# Churn Value              1.000000     0.660772 -0.127463
# Churn Score              0.660772     1.000000 -0.079232
# CLTV                    -0.127463    -0.079232  1.000000

# %% [markdown]
# **services와 status**

# %%
serv_corr=serv_df.corr()
serv_corr
# Out:
#                                    Referred a Friend  Number of Referrals  \
# Referred a Friend                           1.000000             0.708291
# Number of Referrals                         0.708291             1.000000
# Tenure in Months                            0.361844             0.326975
# Phone Service                               0.015418             0.009947
# Avg Monthly Long Distance Charges           0.008702             0.006336
# Multiple Lines                              0.132641             0.078080
# Internet Service                            0.002842            -0.038984
# Avg Monthly GB Download                     0.055003             0.038575
# Online Security                             0.139510             0.142416
# Online Backup                               0.143177             0.112369
# Device Protection Plan                      0.154197             0.116695
# Premium Tech Support                        0.121772             0.107725
# Streaming TV                                0.119882             0.079687
# Streaming Movies                            0.115328             0.057821
# Streaming Music                             0.089917             0.051349
# Unlimited Data                              0.019014            -0.005813
# Paperless Billing                          -0.011095            -0.044888
# Monthly Charge                              0.094101             0.028173
# Total Charges                               0.304199             0.250378
# Total Refunds                               0.038250             0.024756
# Total Extra Data Charges                    0.020150             0.000350
# Total Long Distance Charges                 0.250769             0.216190
# Total Revenue                               0.314777             0.261853
# Satisfaction Score                          0.077764             0.188926
# Churn Value                                -0.149122            -0.286540
# Churn Score                                -0.106648            -0.202209
# CLTV                                        0.125249             0.122843
#
#                                    Tenure in Months  Phone Service  \
# Referred a Friend                          0.361844       0.015418
# Number of Referrals                        0.326975       0.009947
# Tenure in Months                           1.000000       0.008271
# Phone Service                              0.008271       1.000000
# Avg Monthly Long Distance Charges          0.014596       0.486673
# Multiple Lines                             0.332101       0.279690
# Internet Service                           0.038582      -0.172209
# Avg Monthly GB Download                    0.049119      -0.102748
# Online Security                            0.327543      -0.092893
# Online Backup                              0.360558      -0.052312
# Device Protection Plan                     0.360935      -0.071227
# Premium Tech Support                       0.324554      -0.096340
# Streaming TV                               0.279928      -0.022574
# Streaming Movies                           0.285926      -0.032959
# Streaming Music                            0.238082      -0.039252
# Unlimited Data                             0.031194      -0.122395
# Paperless Billing                          0.005743       0.016505
# Monthly Charge                             0.247582       0.247398
# Total Charges                              0.826074       0.113106
# Total Refunds                              0.059021       0.006331
# Total Extra Data Charges                   0.082266      -0.030620
# Total Long Distance Charges                0.674149       0.289728
# Total Revenue                              0.853146       0.174788
# Satisfaction Score                         0.210557       0.013601
# Churn Value                               -0.352861       0.011942
# Churn Score                               -0.224982       0.024664
# CLTV                                       0.396292       0.023015
#
#                                    Avg Monthly Long Distance Charges  \
# Referred a Friend                                           0.008702
# Number of Referrals                                         0.006336
# Tenure in Months                                            0.014596
# Phone Service                                               0.486673
# Avg Monthly Long Distance Charges                           1.000000
# Multiple Lines                                              0.136004
# Internet Service                                           -0.068605
# Avg Monthly GB Download                                    -0.030455
# Online Security                                            -0.028108
# Online Backup                                              -0.013909
# Device Protection Plan                                     -0.031869
# Premium Tech Support                                       -0.048217
# Streaming TV                                                0.001641
# Streaming Movies                                            0.003612
# Streaming Music                                             0.008044
# Unlimited Data                                             -0.053273
# Paperless Billing                                           0.018673
# Monthly Charge                                              0.138396
# Total Charges                                               0.069500
# Total Refunds                                              -0.018644
# Total Extra Data Charges                                    0.002414
# Total Long Distance Charges                                 0.599828
# Total Revenue                                               0.232291
# Satisfaction Score                                          0.001146
# Churn Value                                                 0.008120
# Churn Score                                                 0.021857
# CLTV                                                        0.023858
#
#                                    Multiple Lines  Internet Service  \
# Referred a Friend                        0.132641          0.002842
# Number of Referrals                      0.078080         -0.038984
# Tenure in Months                         0.332101          0.038582
# Phone Service                            0.279690         -0.172209
# Avg Monthly Long Distance Charges        0.136004         -0.068605
# Multiple Lines                           1.000000          0.210564
# Internet Service                         0.210564          1.000000
# Avg Monthly GB Download                  0.091679          0.528450
# Online Security                          0.098108          0.333403
# Online Backup                            0.202237          0.381593
# Device Protection Plan                   0.201137          0.380754
# Premium Tech Support                     0.100571          0.336298
# Streaming TV                             0.257152          0.415552
# Streaming Movies                         0.258751          0.418675
# Streaming Music                          0.193362          0.388693
# Unlimited Data                           0.159669          0.755734
# Paperless Billing                        0.163530          0.321013
# Monthly Charge                           0.490434          0.763557
# Total Charges                            0.468615          0.375269
# Total Refunds                            0.045491          0.020515
# Total Extra Data Charges                 0.064443          0.143736
# Total Long Distance Charges              0.323165         -0.013128
# Total Revenue                            0.466583          0.294141
# Satisfaction Score                      -0.054236         -0.264526
# Churn Value                              0.040102          0.227890
# Churn Score                              0.043143          0.144000
# CLTV                                     0.133568          0.011521
#
#                                    Avg Monthly GB Download  Online Security  \
# Referred a Friend                                 0.055003         0.139510
# Number of Referrals                               0.038575         0.142416
# Tenure in Months                                  0.049119         0.327543
# Phone Service                                    -0.102748        -0.092893
# Avg Monthly Long Distance Charges                -0.030455        -0.028108
# Multiple Lines                                    0.091679         0.098108
# Internet Service                                  0.528450         0.333403
# Avg Monthly GB Download                           1.000000         0.234738
# Online Security                                   0.234738         1.000000
# Online Backup                                     0.229254         0.283832
# Device Protection Plan                            0.225877         0.275438
# Premium Tech Support                              0.223924         0.354931
# Streaming TV                                      0.227715         0.176207
# Streaming Movies                                  0.231211         0.187398
# Streaming Music                                   0.323998         0.195604
# Unlimited Data                                    0.395209         0.265037
# Paperless Billing                                 0.142999        -0.003636
# Monthly Charge                                    0.391787         0.296594
# Total Charges                                     0.223268         0.411922
# Total Refunds                                     0.002397         0.008190
# Total Extra Data Charges                          0.088939         0.058889
# Total Long Distance Charges                       0.011373         0.200477
# Total Revenue                                     0.180726         0.385542
# Satisfaction Score                               -0.091657        -0.093158
# Churn Value                                       0.048868        -0.171226
# Churn Score                                       0.022421        -0.117410
# CLTV                                              0.023043         0.138354
#
#                                    Online Backup  ...  Monthly Charge  \
# Referred a Friend                       0.143177  ...        0.094101
# Number of Referrals                     0.112369  ...        0.028173
# Tenure in Months                        0.360558  ...        0.247582
# Phone Service                          -0.052312  ...        0.247398
# Avg Monthly Long Distance Charges      -0.013909  ...        0.138396
# Multiple Lines                          0.202237  ...        0.490434
# Internet Service                        0.381593  ...        0.763557
# Avg Monthly GB Download                 0.229254  ...        0.391787
# Online Security                         0.283832  ...        0.296594
# Online Backup                           1.000000  ...        0.441780
# Device Protection Plan                  0.303546  ...        0.482692
# Premium Tech Support                    0.294233  ...        0.338304
# Streaming TV                            0.282106  ...        0.629603
# Streaming Movies                        0.274501  ...        0.627429
# Streaming Music                         0.245559  ...        0.536270
# Unlimited Data                          0.283855  ...        0.582484
# Paperless Billing                       0.126735  ...        0.352150
# Monthly Charge                          0.441780  ...        1.000000
# Total Charges                           0.509507  ...        0.651236
# Total Refunds                           0.016855  ...        0.033482
# Total Extra Data Charges                0.095852  ...        0.126244
# Total Long Distance Charges             0.239873  ...        0.246300
# Total Revenue                           0.474667  ...        0.588887
# Satisfaction Score                      0.003252  ...       -0.223922
# Churn Value                            -0.082255  ...        0.193356
# Churn Score                            -0.048030  ...        0.132115
# CLTV                                    0.138610  ...        0.098693
#
#                                    Total Charges  Total Refunds  \
# Referred a Friend                       0.304199       0.038250
# Number of Referrals                     0.250378       0.024756
# Tenure in Months                        0.826074       0.059021
# Phone Service                           0.113106       0.006331
# Avg Monthly Long Distance Charges       0.069500      -0.018644
# Multiple Lines                          0.468615       0.045491
# Internet Service                        0.375269       0.020515
# Avg Monthly GB Download                 0.223268       0.002397
# Online Security                         0.411922       0.008190
# Online Backup                           0.509507       0.016855
# Device Protection Plan                  0.522255       0.026038
# Premium Tech Support                    0.432146       0.034823
# Streaming TV                            0.515217       0.021796
# Streaming Movies                        0.520130       0.013587
# Streaming Music                         0.440462       0.003212
# Unlimited Data                          0.288220       0.011101
# Paperless Billing                       0.158442       0.003966
# Monthly Charge                          0.651236       0.033482
# Total Charges                           1.000000       0.039558
# Total Refunds                           0.039558       1.000000
# Total Extra Data Charges                0.121859       0.016755
# Total Long Distance Charges             0.610185       0.028113
# Total Revenue                           0.972212       0.036984
# Satisfaction Score                      0.068950       0.024221
# Churn Value                            -0.198546      -0.033709
# Churn Score                            -0.123961      -0.013516
# CLTV                                    0.341947       0.007992
#
#                                    Total Extra Data Charges  \
# Referred a Friend                                  0.020150
# Number of Referrals                                0.000350
# Tenure in Months                                   0.082266
# Phone Service                                     -0.030620
# Avg Monthly Long Distance Charges                  0.002414
# Multiple Lines                                     0.064443
# Internet Service                                   0.143736
# Avg Monthly GB Download                            0.088939
# Online Security                                    0.058889
# Online Backup                                      0.095852
# Device Protection Plan                             0.073985
# Premium Tech Support                               0.087941
# Streaming TV                                       0.072300
# Streaming Movies                                   0.094445
# Streaming Music                                    0.079644
# Unlimited Data                                    -0.392720
# Paperless Billing                                  0.038718
# Monthly Charge                                     0.126244
# Total Charges                                      0.121859
# Total Refunds                                      0.016755
# Total Extra Data Charges                           1.000000
# Total Long Distance Charges                        0.058871
# Total Revenue                                      0.122496
# Satisfaction Score                                -0.010472
# Churn Value                                        0.007139
# Churn Score                                        0.008343
# CLTV                                               0.042540
#
#                                    Total Long Distance Charges  Total Revenue  \
# Referred a Friend                                     0.250769       0.314777
# Number of Referrals                                   0.216190       0.261853
# Tenure in Months                                      0.674149       0.853146
# Phone Service                                         0.289728       0.174788
# Avg Monthly Long Distance Charges                     0.599828       0.232291
# Multiple Lines                                        0.323165       0.466583
# Internet Service                                     -0.013128       0.294141
# Avg Monthly GB Download                               0.011373       0.180726
# Online Security                                       0.200477       0.385542
# Online Backup                                         0.239873       0.474667
# Device Protection Plan                                0.210057       0.475723
# Premium Tech Support                                  0.182076       0.396282
# Streaming TV                                          0.182302       0.461952
# Streaming Movies                                      0.186478       0.467288
# Streaming Music                                       0.151411       0.393812
# Unlimited Data                                       -0.009185       0.221781
# Paperless Billing                                     0.018924       0.131239
# Monthly Charge                                        0.246300       0.588887
# Total Charges                                         0.610185       0.972212
# Total Refunds                                         0.028113       0.036984
# Total Extra Data Charges                              0.058871       0.122496
# Total Long Distance Charges                           1.000000       0.778559
# Total Revenue                                         0.778559       1.000000
# Satisfaction Score                                    0.136783       0.094796
# Churn Value                                          -0.223756      -0.223003
# Churn Score                                          -0.135823      -0.138072
# CLTV                                                  0.282189       0.354198
#
#                                    Satisfaction Score  Churn Value  \
# Referred a Friend                            0.077764    -0.149122
# Number of Referrals                          0.188926    -0.286540
# Tenure in Months                             0.210557    -0.352861
# Phone Service                                0.013601     0.011942
# Avg Monthly Long Distance Charges            0.001146     0.008120
# Multiple Lines                              -0.054236     0.040102
# Internet Service                            -0.264526     0.227890
# Avg Monthly GB Download                     -0.091657     0.048868
# Online Security                             -0.093158    -0.171226
# Online Backup                                0.003252    -0.082255
# Device Protection Plan                      -0.000549    -0.066160
# Premium Tech Support                         0.050086    -0.164674
# Streaming TV                                -0.083323     0.063228
# Streaming Movies                            -0.086121     0.061382
# Streaming Music                             -0.073268     0.045587
# Unlimited Data                              -0.210489     0.166545
# Paperless Billing                           -0.156436     0.191825
# Monthly Charge                              -0.223922     0.193356
# Total Charges                                0.068950    -0.198546
# Total Refunds                                0.024221    -0.033709
# Total Extra Data Charges                    -0.010472     0.007139
# Total Long Distance Charges                  0.136783    -0.223756
# Total Revenue                                0.094796    -0.223003
# Satisfaction Score                           1.000000    -0.754649
# Churn Value                                 -0.754649     1.000000
# Churn Score                                 -0.495144     0.660772
# CLTV                                         0.075811    -0.127463
#
#                                    Churn Score      CLTV
# Referred a Friend                    -0.106648  0.125249
# Number of Referrals                  -0.202209  0.122843
# Tenure in Months                     -0.224982  0.396292
# Phone Service                         0.024664  0.023015
# Avg Monthly Long Distance Charges     0.021857  0.023858
# Multiple Lines                        0.043143  0.133568
# Internet Service                      0.144000  0.011521
# Avg Monthly GB Download               0.022421  0.023043
# Online Security                      -0.117410  0.138354
# Online Backup                        -0.048030  0.138610
# Device Protection Plan               -0.055596  0.120394
# Premium Tech Support                 -0.106246  0.119132
# Streaming TV                          0.039585  0.104889
# Streaming Movies                      0.047025  0.113000
# Streaming Music                       0.028240  0.096560
# Unlimited Data                        0.105057 -0.001685
# Paperless Billing                     0.128606  0.011501
# Monthly Charge                        0.132115  0.098693
# Total Charges                        -0.123961  0.341947
# Total Refunds                        -0.013516  0.007992
# Total Extra Data Charges              0.008343  0.042540
# Total Long Distance Charges          -0.135823  0.282189
# Total Revenue                        -0.138072  0.354198
# Satisfaction Score                   -0.495144  0.075811
# Churn Value                           0.660772 -0.127463
# Churn Score                           1.000000 -0.079232
# CLTV                                 -0.079232  1.000000
#
# [27 rows x 27 columns]

# %% [markdown]
# **status별 시각화**
# - 어떤 데이터를 label로 사용해야할까?
# - 결론
#   - Satisfaction Score Churn Value가 강한 반비례 관계(-0.754649)
#   - Churn Score와와 Churn Value가 강한 비례 관계(0.660772)

# %%
# demograpics 파일읽기, 불러오기
Telco_customer_churn_status_df = pd.read_excel('/content/Telco_customer_churn_status.xlsx')
Telco_customer_churn_status_df
# Out:
#        Status ID Customer ID  Count Quarter  Satisfaction Score  \
# 0     SWSORB1252  8779-QRDMV      1      Q3                   3
# 1     SNAEQA8572  7495-OOKFY      1      Q3                   3
# 2     LMBQNN3714  1658-BYGOY      1      Q3                   2
# 3     VRZYZI9978  4598-XLKNJ      1      Q3                   2
# 4     FDNAKX1688  4846-WHAFZ      1      Q3                   2
# ...          ...         ...    ...     ...                 ...
# 7038  HNJTLH8249  2569-WGERO      1      Q3                   5
# 7039  SJJDWW6147  6840-RESVB      1      Q3                   3
# 7040  AODCBE7865  2234-XADUH      1      Q3                   4
# 7041  GLQPEW3973  4801-JZAZL      1      Q3                   4
# 7042  KCNRPQ8327  3186-AJIEK      1      Q3                   4
#
#      Customer Status Churn Label  Churn Value  Churn Score  CLTV  \
# 0            Churned         Yes            1           91  5433
# 1            Churned         Yes            1           69  5302
# 2            Churned         Yes            1           81  3179
# 3            Churned         Yes            1           88  5337
# 4            Churned         Yes            1           67  2793
# ...              ...         ...          ...          ...   ...
# 7038          Stayed          No            0           45  5306
# 7039          Stayed          No            0           59  2140
# 7040          Stayed          No            0           71  5560
# 7041          Stayed          No            0           59  2793
# 7042          Stayed          No            0           38  5097
#
#        Churn Category                  Churn Reason
# 0          Competitor  Competitor offered more data
# 1          Competitor  Competitor made better offer
# 2          Competitor  Competitor made better offer
# 3     Dissatisfaction     Limited range of services
# 4               Price            Extra data charges
# ...               ...                           ...
# 7038              NaN                           NaN
# 7039              NaN                           NaN
# 7040              NaN                           NaN
# 7041              NaN                           NaN
# 7042              NaN                           NaN
#
# [7043 rows x 12 columns]

# %%
status_df = Telco_customer_churn_status_df[["Satisfaction Score","Churn Value","Churn Score","CLTV"]]
status_df
# Out:
#       Satisfaction Score  Churn Value  Churn Score  CLTV
# 0                      3            1           91  5433
# 1                      3            1           69  5302
# 2                      2            1           81  3179
# 3                      2            1           88  5337
# 4                      2            1           67  2793
# ...                  ...          ...          ...   ...
# 7038                   5            0           45  5306
# 7039                   3            0           59  2140
# 7040                   4            0           71  5560
# 7041                   4            0           59  2793
# 7042                   4            0           38  5097
#
# [7043 rows x 4 columns]

# %%
stat_corr=status_df.corr()
stat_corr
# Out:
#                     Satisfaction Score  Churn Value  Churn Score      CLTV
# Satisfaction Score            1.000000    -0.754649    -0.495144  0.075811
# Churn Value                  -0.754649     1.000000     0.660772 -0.127463
# Churn Score                  -0.495144     0.660772     1.000000 -0.079232
# CLTV                          0.075811    -0.127463    -0.079232  1.000000

# %%
reason_df = Telco_customer_churn_status_df[["Churn Category","Churn Reason"]]
reason_df
# Out:
#        Churn Category                  Churn Reason
# 0          Competitor  Competitor offered more data
# 1          Competitor  Competitor made better offer
# 2          Competitor  Competitor made better offer
# 3     Dissatisfaction     Limited range of services
# 4               Price            Extra data charges
# ...               ...                           ...
# 7038              NaN                           NaN
# 7039              NaN                           NaN
# 7040              NaN                           NaN
# 7041              NaN                           NaN
# 7042              NaN                           NaN
#
# [7043 rows x 2 columns]
# <h4 class="colab-quickchart-section-title">Categorical distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# import numpy as np
# from google.colab import autoviz
#
# def categorical_histogram(df, colname, figscale=1, mpl_palette_name='Dark2'):
#   from matplotlib import pyplot as plt
#   import seaborn as sns
#   df.groupby(colname).size().plot(kind='barh', color=sns.palettes.mpl_palette(mpl_palette_name), figsize=(8*figscale, 4.8*figscale))
#   plt.gca().spines[['top', 'right',]].set_visible(False)
#   return autoviz.MplChart.from_current_mpl_state()
#
# chart = categorical_histogram(reason_df, *['Churn Category'], **{})
# chart

# %% [markdown]
# ## **상관관계 시각화**

# %%
# 히트맵 생성
plt.figure(figsize=(20, 20))
sns.clustermap(demo_corr,
               annot=True,
               cmap='RdYlBu_r',
               vmin=-1, vmax=1)
plt.show()

# %%
# 히트맵 생성
plt.figure(figsize=(20, 20))
sns.clustermap(serv_corr,
               annot=True,
               cmap='RdYlBu_r',
               vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# # **Categorical Data**

# %%
# demograpics 파일읽기, 불러오기
cate_demo_df = pd.read_excel('/content/categorical_demographics.xlsx')
cate_demo_df
# Out:
#       Gender  Age  Age Group Under 30 Senior Citizen Married Dependents  \
# 0       Male   78         70       No            Yes      No         No
# 1     Female   74         70       No            Yes     Yes        Yes
# 2       Male   71         70       No            Yes      No        Yes
# 3     Female   78         70       No            Yes     Yes        Yes
# 4     Female   80         80       No            Yes     Yes        Yes
# ...      ...  ...        ...      ...            ...     ...        ...
# 7038  Female   30         30       No             No      No         No
# 7039    Male   38         30       No             No     Yes        Yes
# 7040  Female   30         30       No             No     Yes        Yes
# 7041  Female   32         30       No             No     Yes        Yes
# 7042    Male   44         40       No             No      No         No
#
#       Number of Dependents  Satisfaction Score Customer Status Churn Label  \
# 0                        0                   3         Churned         Yes
# 1                        1                   3         Churned         Yes
# 2                        3                   2         Churned         Yes
# 3                        1                   2         Churned         Yes
# 4                        1                   2         Churned         Yes
# ...                    ...                 ...             ...         ...
# 7038                     0                   5          Stayed          No
# 7039                     2                   3          Stayed          No
# 7040                     2                   4          Stayed          No
# 7041                     2                   4          Stayed          No
# 7042                     0                   4          Stayed          No
#
#       Churn Value  Churn Score  CLTV   Churn Category  \
# 0               1           91  5433       Competitor
# 1               1           69  5302       Competitor
# 2               1           81  3179       Competitor
# 3               1           88  5337  Dissatisfaction
# 4               1           67  2793            Price
# ...           ...          ...   ...              ...
# 7038            0           45  5306              NaN
# 7039            0           59  2140              NaN
# 7040            0           71  5560              NaN
# 7041            0           59  2793              NaN
# 7042            0           38  5097              NaN
#
#                       Churn Reason
# 0     Competitor offered more data
# 1     Competitor made better offer
# 2     Competitor made better offer
# 3        Limited range of services
# 4               Extra data charges
# ...                            ...
# 7038                           NaN
# 7039                           NaN
# 7040                           NaN
# 7041                           NaN
# 7042                           NaN
#
# [7043 rows x 16 columns]

# %% [markdown]
# ## **성별 이탈율**
# - 성별 + 이탈여부
# - 결과 : 성별에 따른 만족도 상관관계 낮음

# %%
gender = cate_demo_df[cate_demo_df['Churn Value'] == 1] # 'Churn Value'가 1인 데이터만 필터링

count_data = gender.groupby(['Gender']).size().reset_index(name='Churn Value_Count') # 'Gender'별로 'Churn Value'의 갯수를 계산

fig = px.bar(count_data, x='Gender', y='Churn Value_Count', color='Gender',
             width=600, height=400) # 그래프 생성
fig.update_traces(showlegend=False) # 범례 생략

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="4c33b246-dc4d-4a8f-8d94-5a67600330d8" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("4c33b246-dc4d-4a8f-8d94-5a67600330d8")) {                    Plotly.newPlot(                        "4c33b246-dc4d-4a8f-8d94-5a67600330d8",                        [{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Female","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Female","offsetgroup":"Female","orientation":"v","showlegend":false,"textposition":"auto","x":["Female"],"xaxis":"x","y":[939],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Gender=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Male","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Male","offsetgroup":"Male","orientation":"v","showlegend":false,"textposition":"auto","x":["Male"],"xaxis":"x","y":[930],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl": ...

# %% [markdown]
# ## **나이별 이탈율**
# - 나이 + 이탈여부
# - 결과 : 나이별에 따른 이탈율 비례 관계(특히 70, 80대에 높음)

# %%
age = cate_demo_df[cate_demo_df['Churn Value'] == 1] # 'Churn Value'가 1인 데이터만 필터링

count_data = age.groupby(['Age Group']).size().reset_index(name='Churn Value_Count') # 'Age Group'별로 'Churn Value'의 갯수를 계산

fig = px.bar(count_data, x='Age Group', y='Churn Value_Count', color='Age Group',
             width=600, height=400) # 그래프 생성
fig.update_traces(showlegend=False) # 범례 생략

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="8cfa3946-7184-4dad-9ba3-a651df44643c" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("8cfa3946-7184-4dad-9ba3-a651df44643c")) {                    Plotly.newPlot(                        "8cfa3946-7184-4dad-9ba3-a651df44643c",                        [{"alignmentgroup":"True","hovertemplate":"Age Group=%{marker.color}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[10,20,30,40,50,60,70,80],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[10,20,30,40,50,60,70,80],"xaxis":"x","y":[18,286,309,318,307,307,295,29],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo ...

# %% [markdown]
# ## **고객상태별 이탈율**
# - 고객상태 + 이탈점수 (이탈점수로 하면 stayed와 joined의 차이가 없어서 이탈점수로 함)
# - 결과 : stayed와 joined의 특별한 차이는 없는 것으로 보임

# %%
# 그래프 생성
fig = px.bar(cate_demo_df, x='Customer Status', y='Churn Score', color='Customer Status',
             title='Customer Status에 따른 평균 Churn Score',
             width=600, height=400,
             opacity=1)

fig.update_traces(showlegend=False) # 범례 생략

# 그래프 표시
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b1779a70-a1fe-4177-a1ae-decf1b5fed11" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b1779a70-a1fe-4177-a1ae-decf1b5fed11")) {                    Plotly.newPlot(                        "b1779a70-a1fe-4177-a1ae-decf1b5fed11",                        [{"alignmentgroup":"True","hovertemplate":"Customer Status=%{x}\u003cbr\u003eChurn Score=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Churned","marker":{"color":"#636efa","opacity":1,"pattern":{"shape":""}},"name":"Churned","offsetgroup":"Churned","orientation":"v","showlegend":false,"textposition":"auto","x":["Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned","Churned ...

# %% [markdown]
# ## **결혼여부에 따른 이탈율**
# - 결혼여부 + 이탈여부
# - 결과 : 미혼이 이탈확률이 더 큼

# %%
married = cate_demo_df[cate_demo_df['Churn Value'] == 1]

count_data = married.groupby(['Married']).size().reset_index(name='Churn Value_Count')

fig = px.bar(count_data, x='Married', y='Churn Value_Count', color='Married',
             width=600, height=400)
fig.update_traces(showlegend=False)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="1ec83da2-25bc-448e-ae1a-150897a02735" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1ec83da2-25bc-448e-ae1a-150897a02735")) {                    Plotly.newPlot(                        "1ec83da2-25bc-448e-ae1a-150897a02735",                        [{"alignmentgroup":"True","hovertemplate":"Married=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"No","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"No","offsetgroup":"No","orientation":"v","showlegend":false,"textposition":"auto","x":["No"],"xaxis":"x","y":[1200],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Married=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Yes","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Yes","offsetgroup":"Yes","orientation":"v","showlegend":false,"textposition":"auto","x":["Yes"],"xaxis":"x","y":[669],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatter ...

# %% [markdown]
# ## **부양가족수와 이탈점수**
# - 부양가족수 + 이탈여부
# - 결과 :
#   - 부양가족 수가 없을 경우 강한 이탈 확률을 가짐

# %%
dependents = cate_demo_df[cate_demo_df['Churn Value'] == 1]

count_data = dependents.groupby(['Number of Dependents']).size().reset_index(name='Churn Value_Count')

fig = px.bar(count_data, x='Number of Dependents', y='Churn Value_Count', color='Number of Dependents',
             width=600, height=400)
fig.update_traces(showlegend=False)

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="33a3e3a6-0cb7-4db0-8086-20d691ea763a" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("33a3e3a6-0cb7-4db0-8086-20d691ea763a")) {                    Plotly.newPlot(                        "33a3e3a6-0cb7-4db0-8086-20d691ea763a",                        [{"alignmentgroup":"True","hovertemplate":"Number of Dependents=%{marker.color}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":[0,1,2,3,4,5,6,7],"coloraxis":"coloraxis","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":[0,1,2,3,4,5,6,7],"xaxis":"x","y":[1763,38,33,30,1,2,1,1],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"s ...

# %% [markdown]
# # **Categorical Data - (2)Servies**

# %%
# services 파일읽기, 불러오기
serv_demo_df = pd.read_excel('/content/categorical_services.xlsx')
serv_demo_df
# Out:
#      Referred a Friend  Number of Referrals  Tenure in Months    Offer  \
# 0                   No                    0                 1     None
# 1                  Yes                    1                 8  Offer E
# 2                   No                    0                18  Offer D
# 3                  Yes                    1                25  Offer C
# 4                  Yes                    1                37  Offer C
# ...                ...                  ...               ...      ...
# 7038                No                    0                72     None
# 7039               Yes                    1                24  Offer C
# 7040               Yes                    4                72     None
# 7041               Yes                    1                11     None
# 7042                No                    0                66     None
#
#      Phone Service  Avg Monthly Long Distance Charges Multiple Lines  \
# 0               No                               0.00             No
# 1              Yes                              48.85            Yes
# 2              Yes                              11.33            Yes
# 3              Yes                              19.76             No
# 4              Yes                               6.33            Yes
# ...            ...                                ...            ...
# 7038           Yes                              22.77             No
# 7039           Yes                              36.05            Yes
# 7040           Yes                              29.66            Yes
# 7041            No                               0.00             No
# 7042           Yes                              30.96             No
#
#      Internet Service Internet Type  Avg Monthly GB Download  ...  \
# 0                 Yes           DSL                        8  ...
# 1                 Yes   Fiber Optic                       17  ...
# 2                 Yes   Fiber Optic                       52  ...
# 3                 Yes   Fiber Optic                       12  ...
# 4                 Yes   Fiber Optic                       14  ...
# ...               ...           ...                      ...  ...
# 7038               No          None                        0  ...
# 7039              Yes         Cable                       24  ...
# 7040              Yes   Fiber Optic                       59  ...
# 7041              Yes           DSL                       17  ...
# 7042              Yes   Fiber Optic                       11  ...
#
#      Total Extra Data Charges Total Long Distance Charges Total Revenue  \
# 0                          20                        0.00         59.65
# 1                           0                      390.80       1024.10
# 2                           0                      203.94       1910.88
# 3                           0                      494.00       2995.07
# 4                           0                      234.21       3102.36
# ...                       ...                         ...           ...
# 7038                        0                     1639.44       3039.53
# 7039                        0                      865.20       2807.47
# 7040                        0                     2135.52       9453.04
# 7041                        0                        0.00        319.21
# 7042                        0                     2043.36       8887.86
#
#      Customer Status Churn Label Churn Value Churn Score  CLTV  \
# 0            Churned         Yes           1          91  5433
# 1            Churned         Yes           1          69  5302
# 2            Churned         Yes           1          81  3179
# 3            Churned         Yes           1          88  5337
# 4            Churned         Yes           1          67  2793
# ...              ...         ...         ...         ...   ...
# 7038          Stayed          No           0          45  5306
# 7039          Stayed          No           0          59  2140
# 7040          Stayed          No           0          71  5560
# 7041          Stayed          No           0          59  2793
# 7042          Stayed          No           0          38  5097
#
#        Churn Category                  Churn Reason
# 0          Competitor  Competitor offered more data
# 1          Competitor  Competitor made better offer
# 2          Competitor  Competitor made better offer
# 3     Dissatisfaction     Limited range of services
# 4               Price            Extra data charges
# ...               ...                           ...
# 7038              NaN                           NaN
# 7039              NaN                           NaN
# 7040              NaN                           NaN
# 7041              NaN                           NaN
# 7042              NaN                           NaN
#
# [7043 rows x 34 columns]

# %% [markdown]
# ## **마케팅 제안에 따른 이탈율**
# - 마케팅 제안 종류 + 이탈여부
# - 결과 : 어떤 마케팅인지 알수 없지만, 추후 이 데이터를 활용할 때 활용하면 좋을듯

# %%
offer = serv_demo_df[cate_demo_df['Churn Value'] == 1]

count_data = offer.groupby(['Offer']).size().reset_index(name='Churn Value_Count')

fig = px.bar(count_data, x='Offer', y='Churn Value_Count', color='Offer',
             width=600, height=400)
fig.update_traces(showlegend=False)

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="e6baf341-f298-487e-9ac1-c58b8dcf988d" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e6baf341-f298-487e-9ac1-c58b8dcf988d")) {                    Plotly.newPlot(                        "e6baf341-f298-487e-9ac1-c58b8dcf988d",                        [{"alignmentgroup":"True","hovertemplate":"Offer=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"None","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"textposition":"auto","x":["None"],"xaxis":"x","y":[1051],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Offer=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Offer A","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Offer A","offsetgroup":"Offer A","orientation":"v","showlegend":false,"textposition":"auto","x":["Offer A"],"xaxis":"x","y":[35],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Offer=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Offer B","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Offer B","offsetgroup":"Offer B","orientation":"v","showlegend":false,"textposition":"auto","x":["Offer B"],"xaxis":"x","y":[101],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Offer=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Offer C","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Offer C","offsetgroup":"Offer C","orientation":"v","showlegend":false,"textposition":"auto","x":["Offer C"],"xaxis":"x","y":[95],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Offer=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Offer D","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Offer D","offsetgroup":"Offer D","orientation":"v","showlegend":false,"textposition":"auto","x":["Offer D"],"xaxis":"x","y":[161],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Offer=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Offer E","marker":{"color":"#19d3f3","pattern":{"shape":""}},"name":"Offer E","offsetgroup":"Offer E","orientation":"v","showlegend":false,"textposition":"auto","x":["Offer E"],"xaxis":"x","y":[426],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#f ...

# %% [markdown]
# ## **인터넷 서비스(Internet Type)에 따른 이탈율**
# - 인터넷 이용 타입 + 이탈여부
# - 결과 : Fiber Optic사용자가 가장 이탈을 많이하고, cable 사용자가 가장 이탈을 적게함

# %%
internet_type = serv_demo_df[cate_demo_df['Churn Value'] == 1]

count_data = internet_type.groupby(['Internet Type']).size().reset_index(name='Churn Value_Count')

fig = px.bar(count_data, x='Internet Type', y='Churn Value_Count', color='Internet Type',
             width=600, height=400)
fig.update_traces(showlegend=False)

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c042cc0d-61f6-487a-8c78-c7e8325a904e" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c042cc0d-61f6-487a-8c78-c7e8325a904e")) {                    Plotly.newPlot(                        "c042cc0d-61f6-487a-8c78-c7e8325a904e",                        [{"alignmentgroup":"True","hovertemplate":"Internet Type=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Cable","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Cable","offsetgroup":"Cable","orientation":"v","showlegend":false,"textposition":"auto","x":["Cable"],"xaxis":"x","y":[213],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Internet Type=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"DSL","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"DSL","offsetgroup":"DSL","orientation":"v","showlegend":false,"textposition":"auto","x":["DSL"],"xaxis":"x","y":[307],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Internet Type=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Fiber Optic","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Fiber Optic","offsetgroup":"Fiber Optic","orientation":"v","showlegend":false,"textposition":"auto","x":["Fiber Optic"],"xaxis":"x","y":[1236],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Internet Type=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"None","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"None","offsetgroup":"None","orientation":"v","showlegend":false,"textposition":"auto","x":["None"],"xaxis":"x","y":[113],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.55555 ...

# %% [markdown]
# ## **계약방식 (Contract)에 따른 이탈율**
# - Contract + 이탈율
# - 결과: 짧은 계약기간을 선택할수록 이탈확률이 높음

# %%
contract = serv_demo_df[cate_demo_df['Churn Value'] == 1]

count_data = contract.groupby(['Contract']).size().reset_index(name='Churn Value_Count')

fig = px.bar(count_data, x='Contract', y='Churn Value_Count', color='Contract',
             width=600, height=400)
fig.update_traces(showlegend=False)

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="6f5f94ae-2f07-4cd9-87eb-1264db84b624" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6f5f94ae-2f07-4cd9-87eb-1264db84b624")) {                    Plotly.newPlot(                        "6f5f94ae-2f07-4cd9-87eb-1264db84b624",                        [{"alignmentgroup":"True","hovertemplate":"Contract=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Month-to-Month","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Month-to-Month","offsetgroup":"Month-to-Month","orientation":"v","showlegend":false,"textposition":"auto","x":["Month-to-Month"],"xaxis":"x","y":[1655],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Contract=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"One Year","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"One Year","offsetgroup":"One Year","orientation":"v","showlegend":false,"textposition":"auto","x":["One Year"],"xaxis":"x","y":[166],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Contract=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Two Year","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Two Year","offsetgroup":"Two Year","orientation":"v","showlegend":false,"textposition":"auto","x":["Two Year"],"xaxis":"x","y":[48],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444 ...

# %% [markdown]
# ## **결제방식 (Payment Method)에 따른 이탈율**
# - Payment Method + 이탈율
# - 결과: 은행인출-> 신용카드-> 우표결제순으로 이탈 확률이 높음

# %%
payment = serv_demo_df[cate_demo_df['Churn Value'] == 1]

count_data = payment.groupby(['Payment Method']).size().reset_index(name='Churn Value_Count')

fig = px.bar(count_data, x='Payment Method', y='Churn Value_Count', color='Payment Method',
             width=600, height=400)
fig.update_traces(showlegend=False)

fig.show() # 그래프 표시
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="2630c76b-43b0-4700-9339-179c64f89ba7" class="plotly-graph-div" style="height:400px; width:600px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2630c76b-43b0-4700-9339-179c64f89ba7")) {                    Plotly.newPlot(                        "2630c76b-43b0-4700-9339-179c64f89ba7",                        [{"alignmentgroup":"True","hovertemplate":"Payment Method=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Bank Withdrawal","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Bank Withdrawal","offsetgroup":"Bank Withdrawal","orientation":"v","showlegend":false,"textposition":"auto","x":["Bank Withdrawal"],"xaxis":"x","y":[1329],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Payment Method=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Credit Card","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Credit Card","offsetgroup":"Credit Card","orientation":"v","showlegend":false,"textposition":"auto","x":["Credit Card"],"xaxis":"x","y":[398],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Payment Method=%{x}\u003cbr\u003eChurn Value_Count=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Mailed Check","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"Mailed Check","offsetgroup":"Mailed Check","orientation":"v","showlegend":false,"textposition":"auto","x":["Mailed Check"],"xaxis":"x","y":[142],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222," ...
