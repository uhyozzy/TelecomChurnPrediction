# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#고객-등급-분류" data-toc-modified-id="고객-등급-분류-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>고객 등급 분류</a></span><ul class="toc-item"><li><span><a href="#CLTV" data-toc-modified-id="CLTV-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>CLTV</a></span></li><li><span><a href="#Total-Revenue" data-toc-modified-id="Total-Revenue-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Total Revenue</a></span></li><li><span><a href="#Tenure-그룹별-CLTV" data-toc-modified-id="Tenure-그룹별-CLTV-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Tenure 그룹별 CLTV</a></span></li><li><span><a href="#CLTV-별-이탈율" data-toc-modified-id="CLTV-별-이탈율-1.4"><span class="toc-item-num">1.4&nbsp;&nbsp;</span>CLTV 별 이탈율</a></span></li></ul></li><li><span><a href="#결과값-코드-구현" data-toc-modified-id="결과값-코드-구현-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>결과값 코드 구현</a></span><ul class="toc-item"><li><span><a href="#고객-세그먼트-및-예외-변수-사항-파악" data-toc-modified-id="고객-세그먼트-및-예외-변수-사항-파악-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>고객 세그먼트 및 예외 변수 사항 파악</a></span><ul class="toc-item"><li><span><a href="#CLTV-높은-고가치-기업-고객" data-toc-modified-id="CLTV-높은-고가치-기업-고객-2.1.1"><span class="toc-item-num">2.1.1&nbsp;&nbsp;</span>CLTV 높은 고가치 기업 고객</a></span></li><li><span><a href="#CLTV-높은-고가치-개인-고객" data-toc-modified-id="CLTV-높은-고가치-개인-고객-2.1.2"><span class="toc-item-num">2.1.2&nbsp;&nbsp;</span>CLTV 높은 고가치 개인 고객</a></span></li><li><span><a href="#CLTV-중간-가치-기업-고객(잠재적-이탈)-(4001~6000)" data-toc-modified-id="CLTV-중간-가치-기업-고객(잠재적-이탈)-(4001~6000)-2.1.3"><span class="toc-item-num">2.1.3&nbsp;&nbsp;</span>CLTV 중간 가치 기업 고객(잠재적 이탈) (4001~6000)</a></span></li><li><span><a href="#CLTV-중간--가치-개인-고객(잠재적-이탈)" data-toc-modified-id="CLTV-중간--가치-개인-고객(잠재적-이탈)-2.1.4"><span class="toc-item-num">2.1.4&nbsp;&nbsp;</span>CLTV 중간  가치 개인 고객(잠재적 이탈)</a></span></li><li><span><a href="#CLTV-아직은-낮지만-수익-가치가-높은-기업-고객" data-toc-modified-id="CLTV-아직은-낮지만-수익-가치가-높은-기업-고객-2.1.5"><span class="toc-item-num">2.1.5&nbsp;&nbsp;</span>CLTV 아직은 낮지만 수익 가치가 높은 기업 고객</a></span></li><li><span><a href="#CLTV-낮지만-수익-가치가-중간-가치-기업-고객" data-toc-modified-id="CLTV-낮지만-수익-가치가-중간-가치-기업-고객-2.1.6"><span class="toc-item-num">2.1.6&nbsp;&nbsp;</span>CLTV 낮지만 수익 가치가 중간 가치 기업 고객</a></span></li><li><span><a href="#CLTV-낮은-저가치-개인-고객" data-toc-modified-id="CLTV-낮은-저가치-개인-고객-2.1.7"><span class="toc-item-num">2.1.7&nbsp;&nbsp;</span>CLTV 낮은 저가치 개인 고객</a></span></li><li><span><a href="#예외-가치-고객-파악" data-toc-modified-id="예외-가치-고객-파악-2.1.8"><span class="toc-item-num">2.1.8&nbsp;&nbsp;</span>예외 가치 고객 파악</a></span></li><li><span><a href="#보완-및-추가해야할-고객층-확인" data-toc-modified-id="보완-및-추가해야할-고객층-확인-2.1.9"><span class="toc-item-num">2.1.9&nbsp;&nbsp;</span>보완 및 추가해야할 고객층 확인</a></span></li></ul></li><li><span><a href="#기업/개인-고객-분류-+-혜택-제안-적용되서-나오게-해보기" data-toc-modified-id="기업/개인-고객-분류-+-혜택-제안-적용되서-나오게-해보기-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>기업/개인 고객 분류 + 혜택 제안 적용되서 나오게 해보기</a></span></li><li><span><a href="#사용할-리텐션-마케팅-제안-함수-코드-부분-(Churn-Value-제외-버전)" data-toc-modified-id="사용할-리텐션-마케팅-제안-함수-코드-부분-(Churn-Value-제외-버전)-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>사용할 리텐션 마케팅 제안 함수 코드 부분 (Churn Value 제외 버전)</a></span></li></ul></li></ul></div>

# %%
import numpy as np
import pandas as pd
import plotly.offline as py # visualization
py.init_notebook_mode(connected=True) # visualization
import plotly.graph_objs as go # visualization
from plotly.subplots import make_subplots
import plotly.figure_factory as ff # visualization
import plotly.express as px 
from plotly.offline import download_plotlyjs, init_notebook_mode, plot, iplot 
import cufflinks as cf 
import warnings
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>

# %%
warnings.filterwarnings('ignore')
cf.go_offline() 
init_notebook_mode(connected=True)
# Out:
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
#                 'plotly': ['https://cdn.plot.ly/plotly-2.26.0.min']
#             }
#         });
#         require(['plotly'], function(Plotly) {
#             window._Plotly = Plotly;
#         });
#         }
#         </script>
#         <script type="text/javascript">
#         window.PlotlyConfig = {MathJaxConfig: 'local'};
#         if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}
#         if (typeof require !== 'undefined') {
#         require.undef("plotly");
#         requirejs.config({
#             paths: {
# ...

# %%
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Graphics in retina format are more sharp and legible
# %config InlineBackend.figure_format = 'retina'

# %%
# unicode minus를 사용하지 않기 위한 설정 (minus 깨짐현상 방지)
plt.rcParams['axes.unicode_minus'] = False
# 한글 텍스트를 제대로 표시하기 위해 'font.family' 사용
plt.rcParams['font.family'] = 'AppleGothic'

# %%
# csv 파일 불러오기
df = pd.read_csv('./data/Churn.csv')

# %%
df.head()
# Out:
#   Customer ID  Age  Number of Dependents Membership  Satisfaction Score  \
# 0  8779-QRDMV   78                     0        NaN                   3
# 1  7495-OOKFY   74                     1    Offer E                   3
# 2  1658-BYGOY   71                     3    Offer D                   2
# 3  4598-XLKNJ   78                     1    Offer C                   2
# 4  4846-WHAFZ   80                     1    Offer C                   2
#
#    Tech services  Streaming services  Combined Product        Contract  \
# 0              1                   1                 2  Month-to-Month
# 1              1                   0                 1  Month-to-Month
# 2              0                   2                 1  Month-to-Month
# 3              2                   2                 1  Month-to-Month
# 4              0                   0                 1  Month-to-Month
#
#    Tenure in Months  Monthly Charge  Total Revenue  Churn Value  CLTV  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           7043 non-null   object
#  1   Age                   7043 non-null   int64
#  2   Number of Dependents  7043 non-null   int64
#  3   Membership            3166 non-null   object
#  4   Satisfaction Score    7043 non-null   int64
#  5   Tech services         7043 non-null   int64
#  6   Streaming services    7043 non-null   int64
#  7   Combined Product      7043 non-null   int64
#  8   Contract              7043 non-null   object
#  9   Tenure in Months      7043 non-null   int64
#  10  Monthly Charge        7043 non-null   float64
#  11  Total Revenue         7043 non-null   float64
#  12  Churn Value           7043 non-null   int64
#  13  CLTV                  7043 non-null   int64
#  14  Total Charges         7043 non-null   float64
# ...

# %%
# 'Membership' 컬럼의 결측치를 "None"으로 대체
df['Membership'].fillna('None', inplace=True)

# %%
# Offer A: 1, Offer B: 2, Offer C: 3, Offer D: 4, Offer E: 5, None: 0 로 변경

df.loc[df["Membership"]=='Offer A', "Membership"] = 1
df.loc[df["Membership"]=='Offer B', "Membership"] = 2
df.loc[df["Membership"]=='Offer C', "Membership"] = 3
df.loc[df["Membership"]=='Offer D', "Membership"] = 4
df.loc[df["Membership"]=='Offer E', "Membership"] = 5
df.loc[df["Membership"]=='None', "Membership"] = 0

df["Membership"] = df["Membership"].astype('int64')

# %%
# Month-to-month:1, One year:12, Two year:24 로 변경
df.loc[df["Contract"]=='Month-to-Month', "Contract"] = 1
df.loc[df["Contract"]=='One Year', "Contract"] = 12
df.loc[df["Contract"]=='Two Year', "Contract"] = 24

df["Contract"] = df["Contract"].astype('int64')

# %%
df['CLTV'].value_counts()
# Out:
# CLTV
# 5546    8
# 5915    7
# 5461    7
# 4741    7
# 5527    7
#        ..
# 3026    1
# 2146    1
# 4140    1
# 2982    1
# 5553    1
# Name: count, Length: 3438, dtype: int64

# %%
df['CLTV'].sort_values().max()
df['CLTV'].sort_values().min()
# Out:
# 6500
# 2003

# %%
len(df[df['CLTV'] < 2000])
len(df[(df['CLTV'] >= 2000) & (df['CLTV'] < 3000)])
len(df[(df['CLTV'] >= 3001) & (df['CLTV'] < 4000)])
len(df[(df['CLTV'] >= 4001) & (df['CLTV'] < 5000)]) 
len(df[df['CLTV'] >= 5000]) # 5000 이상 충성고객
len(df[df['CLTV'] >= 6000])
# Out:
# 0
# 1179
# 1185
# 2100
# 2574
# 426

# %% [markdown]
# ## 고객 등급 분류
#
#     CLTV
#     * 2000-4000: 저가치 고객
#     * 4001-6000: 잠재 이탈율이 큰 고객으로 우리가 눈여겨봐야할 고객층
#     * 6000 이상: 고가치 고객

# %% [markdown]
# ### CLTV

# %%
# CLTV 낮은 저 가치고객
len(df[(df['CLTV'] >= 2000) & (df['CLTV'] < 4000)])
# Out:
# 2367

# %%
# 중간 단계 가치 고객(잠재적 이탈)
len(df[(df['CLTV'] >= 4001) & (df['CLTV'] < 6000)])
# Out:
# 4248

# %%
# CLTV 높은 고가치 고객
len(df[df['CLTV'] >= 6000])
# Out:
# 426

# %%
df['Total Revenue'].sort_values().max()
df['Total Revenue'].sort_values().min()
# Out:
# 11979.34
# 21.36

# %% [markdown]
# ### Total Revenue

# %%
len(df[(df['Total Revenue'] >= 10000) & (df['Total Charges'] >= 6000)])
# Out:
# 123

# %%
len(df[df['Total Revenue'] >= 10000])
# Out:
# 123

# %%
# CLTV 컬럼에서 점수대를 나눔
df['CLTV Group'] = pd.cut(df['CLTV'], bins=[2000, 4000, 6000, 7000], labels=['2000-4000', '4001-6000', '6000+'])

# %%
df['Total Revenue Group'] = pd.cut(df['Total Revenue'], bins=[0, 2000, 6000, 10000, float('inf')], labels=['0-2000', '2001-6000', '6001-10000', '10000+'])

# %%
plt.figure(figsize=(12,5),dpi=200)
sns.countplot(data=df, x='Total Revenue Group', hue='CLTV Group', palette='Set2')
# Out:
# <AxesSubplot:xlabel='Total Revenue Group', ylabel='count'>

# %%
df['Tenure in Months'].sort_values().max()
df['Tenure in Months'].sort_values().min()
# Out:
# 72
# 1

# %%
df['Tenure in Months'].value_counts()
# Out:
# Tenure in Months
# 1     613
# 72    362
# 2     238
# 3     200
# 4     176
#      ...
# 38     59
# 28     57
# 39     56
# 44     51
# 36     50
# Name: count, Length: 72, dtype: int64

# %%
# Tenure in Months 컬럼에서 점수대를 나눔
df['Tenure Group'] = pd.cut(df['Tenure in Months'], bins=[0, 24, 60, 72], labels=['0-24', '24-60', '60+'])

# %% [markdown]
# ### Tenure 그룹별 CLTV

# %% [markdown]
# * 5년 이상
# * 2년 이상 ~ 5년 미만
# * 2년 미만

# %%
plt.figure(figsize=(15,8),dpi=200)
sns.countplot(data=df, x='Tenure Group', hue='CLTV Group', palette='Set2')
# Out:
# <AxesSubplot:xlabel='Tenure Group', ylabel='count'>

# %% [markdown]
# ### CLTV 별 이탈율

# %%
plt.figure(figsize=(15,8),dpi=200)
sns.countplot(data=df, hue='Churn Value', x='CLTV Group', palette='Set2')
# Out:
# <AxesSubplot:xlabel='CLTV Group', ylabel='count'>

# %%
# 'CLTV' 열을 기준으로 데이터프레임 정렬
# df_sorted = df.sort_values(by='CLTV', ascending=False)

# %%
# df_sorted.head()

# %%
# 내림차순 정렬된 csv 파일로 저장
# index 열을 포함하지 않으려면 index=False를 설정
# df_sorted.to_csv('./data/내림차순_churn.csv', index=False)

# %% [markdown]
# ## 결과값 코드 구현

# %% [markdown]
# ### 고객 세그먼트 및 예외 변수 사항 파악

# %% [markdown]
# #### CLTV 높은 고가치 기업 고객

# %%
# 기업 로열티 장기고객 No.1
# CLTV 6000+ 이상, Total Revenue $10,000 이상 
len(df[(df['Total Revenue'] >= 10000) & (df['CLTV'] >= 6000)])
# Out:
# 30

# %%
# 기업 로열티 장기고객 No.1.5
# CLTV 5000 ~ 6000 , Total Revenue $10,000 이상 
len(df[(df['Total Revenue'] >= 10000) & (df['CLTV'] >= 5000) & (df['CLTV'] < 6000)])
# Out:
# 44

# %%
# 기업 로열티 장기고객 No.2
# CLTV 4000 ~ 5000 , Total Revenue $6000 - $10,000 이상 
len(df[(df['Total Revenue'] >= 10000) & (df['CLTV'] >= 4000) & (df['CLTV'] < 5000)])
# Out:
# 49

# %% [markdown]
# #### CLTV 높은 고가치 개인 고객

# %%
# 개인 로열티 장기고객
# 자녀가 있는 가족고객, CLTV 6000 이상, 유지 기간 60개월 이상
len(df[(df['Number of Dependents'] > 0) & (df['CLTV'] >= 6000) & (df['Tenure in Months'] >= 60)])
# Out:
# 100

# %% [markdown]
# #### CLTV 중간 가치 기업 고객(잠재적 이탈) (4001~6000)

# %%
# CLTV 5000 이상 , Total Revenue $4,500 ~ $6,000 
len(df[(df['CLTV'] >= 5000) & (df['Total Revenue'] >= 4500) & (df['CLTV'] < 6000)])
# Out:
# 723

# %%
# CLTV 4001 ~ 5000, Total Revenue $4,500 ~ $6,000 
len(df[(df['CLTV'] >= 4001) & (df['CLTV'] < 5000) & (df['Total Revenue'] >= 2000) & (df['Total Revenue'] < 4500)])
# Out:
# 484

# %% [markdown]
# #### CLTV 중간  가치 개인 고객(잠재적 이탈)

# %%
# CLTV 4000- 6000, 유지기간 36개월 이상의 고객
len(df[(df['CLTV'] >= 4000) & (df['CLTV'] < 6000) & (df['Tenure in Months'] >= 36) & (df['Tenure in Months'] < 60)])
# Out:
# 994

# %% [markdown]
# #### CLTV 아직은 낮지만 수익 가치가 높은 기업 고객

# %%
# CLTV 2000 - 4000, Total Revenue $6,000 이상 
len(df[(df['CLTV'] >= 2000) & (df['CLTV'] < 4000) & (df['Total Revenue'] >= 6000)])
# Out:
# 22

# %% [markdown]
# #### CLTV 낮지만 수익 가치가 중간 가치 기업 고객

# %%
# CLTV 2000 - 4000, Total Revenue $4,000 이상 $6,000 미만
len(df[(df['CLTV'] >= 2000) & (df['CLTV'] < 4000) & (df['Total Revenue'] >=4000) & (df['Total Revenue'] < 6000)])
# Out:
# 231

# %% [markdown]
# #### CLTV 낮은 저가치 개인 고객

# %%
# CLTV 4000미만, 유지기간 24개월 이상
len(df[(df['CLTV'] < 4000) & (df['Tenure in Months'] >= 24) & (df['Tenure in Months'] < 36)])
# Out:
# 427

# %%
# CLTV 4000미만, 유지기간 24개월 미만 
len(df[(df['CLTV'] < 4000) & (df['Tenure in Months'] < 24)])
# Out:
# 1510

# %% [markdown]
# #### 예외 가치 고객 파악

# %%
# CLTV 는 저가치인데 total revenue 가 높을 경우 
# $7,000: 1명
# $6,000: 21명
# $5,000: 78명
# $4,000: 153명
len(df[(df['CLTV'] < 4000) & (df['Total Revenue'] >= 4000)])
# Out:
# 253

# %%
# CLTV 는 고가치인데 total revenue 가 낮을 경우 - 1815명 -> 개인 고객일 가능성이 많음
len(df[(df['CLTV'] >= 5000) & (df['Total Revenue'] < 2000)]) # 개인 고객일 가능성이 큼
len(df[(df['CLTV'] >= 5000) & (df['Total Revenue'] >= 2000) & (df['Total Revenue'] < 3000)])
len(df[(df['CLTV'] >= 5000) & (df['Total Revenue'] >= 3000) & (df['Total Revenue'] < 4000)])
len(df[(df['CLTV'] >= 5000) & (df['Total Revenue'] >= 4000) & (df['Total Revenue'] < 5000)])
len(df[(df['CLTV'] >= 5000) & (df['Total Revenue'] >= 5000) & (df['Total Revenue'] < 6000)])
# Out:
# 905
# 315
# 246
# 180
# 169

# %%
# CLTV 는 중간 단계 고객인데 total revenue 가 낮을 경우 -> 개인 고객일 가능성이 많음
len(df[(df['CLTV'] >= 4001) & (df['CLTV'] < 6000) & (df['Total Revenue'] < 2000)])
# Out:
# 1780

# %% [markdown]
# #### 보완 및 추가해야할 고객층 확인

# %%
# CLTV 2205, Total Revenue $978.81, 유지기간 9달
df[df['Customer ID'] == '0002-ORFBO']
# Out:
#      Customer ID  Age  Number of Dependents  Membership  Satisfaction Score  \
# 4006  0002-ORFBO   37                     0           0                   3
#
#       Tech services  Streaming services  Combined Product  Contract  \
# 4006              2                   1                 2        12
#
#       Tenure in Months  Monthly Charge  Total Revenue  Churn Value  CLTV  \
# 4006                 9            65.6         974.81            0  2205
#
#       Total Charges CLTV Group Total Revenue Group Tenure Group
# 4006          593.3  2000-4000              0-2000         0-24

# %%
# CLTV 2000 - 4000, Total Revenue $978.81, 유지기간 12개월 미만
len(df[(df['CLTV'] >= 2000) & (df['CLTV'] < 4000) & (df['Tenure in Months'] < 24)])
# Out:
# 1510

# %%
filtered_customers = df[(df['CLTV'] >= 2000) & (df['CLTV'] < 4000) & (df['Tenure in Months'] < 24)]
customer_ids = filtered_customers['Customer ID']
print(customer_ids)
# Out:
# 2       1658-BYGOY
# 6       0390-DCFDQ
# 13      7273-TEFQD
# 14      3606-TWKGI
# 15      4385-GZQXV
#            ...
# 7021    9347-AERRL
# 7028    9837-FWLCH
# 7036    8456-QDAVC
# 7037    7750-EYXWZ
# 7041    4801-JZAZL
# Name: Customer ID, Length: 1510, dtype: object

# %%
# CLTV 5000 이상 고가치 고객인데 유지기간이 2년 미만
len(df[(df['CLTV'] <= 5000) & (df['Tenure in Months'] < 24)])
# Out:
# 2307

# %% [markdown]
# ### 기업/개인 고객 분류 + 혜택 제안 적용되서 나오게 해보기

# %%
df['Customer ID']
# Out:
# 0       8779-QRDMV
# 1       7495-OOKFY
# 2       1658-BYGOY
# 3       4598-XLKNJ
# 4       4846-WHAFZ
#            ...
# 7038    2569-WGERO
# 7039    6840-RESVB
# 7040    2234-XADUH
# 7041    4801-JZAZL
# 7042    3186-AJIEK
# Name: Customer ID, Length: 7043, dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 18 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Customer ID           7043 non-null   object
#  1   Age                   7043 non-null   int64
#  2   Number of Dependents  7043 non-null   int64
#  3   Membership            7043 non-null   int64
#  4   Satisfaction Score    7043 non-null   int64
#  5   Tech services         7043 non-null   int64
#  6   Streaming services    7043 non-null   int64
#  7   Combined Product      7043 non-null   int64
#  8   Contract              7043 non-null   int64
#  9   Tenure in Months      7043 non-null   int64
#  10  Monthly Charge        7043 non-null   float64
#  11  Total Revenue         7043 non-null   float64
#  12  Churn Value           7043 non-null   int64
#  13  CLTV                  7043 non-null   int64
#  14  Total Charges         7043 non-null   float64
# ...

# %% [markdown]
# ### 사용할 리텐션 마케팅 제안 함수 코드 부분 (Churn Value 제외 버전)

# %%
# input 함수는 주석 처리 해놓음.
# 컬럼 설명 및 조건별 마케팅 제안 설명 B2B/B2C 로 나누어서 해놨는데 만약 잘못된 부분 있으면 알려주세요.

def get_cltv_description(CLTV, total_revenue, tenure_months, num_dependents):
    """
    ['CLTV']: Amount of total expected value per person that might contribute in the future.
    ['total_revenue']: The total annual earnings from each customer.
    ['tenure_months']: The duration for which each customer has retained their contracts.
    ['num_dependent']: The number of children in family customers.
    
   # Loyalty Class Customers(CLTV 높은 고가치 고객층)
   
   (B2B)
    - CLTV above 6000, total_revenue above $10,000
    Marketing Suggestions:  '결합 할인 + 요금할인(20%)' 제안 가능
    - CLTV between 5000 and 6000, total_revenue above $10,000
    Marketing Suggestions: '결합 할인 + 요금할인(18%)' 제안 가능
    - CLTV between 4000 and 5000, total_revenue between $6,000 and $10,000
    Marketing Suggestions: '결합 할인 + 요금할인(15%)' 제안 가능
    
    (B2C)
    - CLTV above 5000, tenure_months at least above 60 months, num_dependets above 0
    Marketing Suggestions: '결합 할인 + 요금할인(10%)' 제안 가능
    
    
    # Middle Class Customers (Potential customers who might churn)
    
    (B2B)
    - CLTV between 5000 and 6000, total_revenue between $4,500 and $6,000
    Marketing Suggestions: '요금 할인(13%)' 제안 가능
    - CLTV between 4001 and 5000, total_revenue between $2,000 and $4,500
    Marketing Suggestions: '요금 할인(10%)' 제안 가능
    
    (B2C)
    - CLTV between 4000 and 6000, total_revenue tenure_months between 36months and 60months
    Marketing Suggestions: '할인 혜택 or 업그레이드 or 맞춤형' 제안 가능
    
    
    # Lower Class Customer, including exceptions
    
    (B2B) => Business clients who have lower CLTV, but unexpectedly higher total revenue.
    - CLTV between 2000 and 4000, total_revenue above $6,000
    Marketing Suggestions: '요금 할인(15%)' 제안 가능
    - CLTV between 2000 and 4000, total_revenue between $4,000 and $6,000
    Marketing Suggestions: '요금 할인(10%)' 제안 가능
    
    (B2C)
    - CLTV below 4000, tenure_months between 24months and 36months
    Marketing Suggestions: '할인 혜택 or 업그레이드 or 맞춤형' 제안 가능
    - CLTV below 4000, tenure_months less than 24months
    Marketing Suggestions: '업그레이드 or 맞춤형'제안 가능
    # 경우의 수 추가 부분 
     - CLTV above 4000, tenure_months less than 24months
    Marketing Suggestions: '업그레이드 or 맞춤형'제안 가능
    - CLTV between 2000 and 4000, tenure_months less than 24months
     Marketing Suggestions: '제안할 마케팅 없음'

    """
    
    if CLTV >= 6000 and total_revenue >= 10000:
        return "CLTV 높은 고가치 기업 고객님 입니다. '결합 할인 + 요금할인(20%)' 제안 가능합니다."
    elif 5000 <= CLTV < 6000 and total_revenue >= 10000:
        return "CLTV 높은 고가치 기업 고객님 입니다. '결합 할인 + 요금할인(18%)' 제안 가능합니다."
    elif 4000 <= CLTV < 5000 and 6000 >= total_revenue < 10000:
        return "CLTV 높은 고가치 기업 고객님 입니다. '결합 할인 + 요금할인(15%)' 제안 가능합니다."
    elif CLTV >= 5000 and tenure_months >= 60 and num_dependents > 0:
        return "CLTV 높은 고가치 개인 고객님 입니다. '결합 할인 + 요금할인(10%)' 제안 가능합니다."
    elif 5000 <= CLTV < 6000 and 4500 <= total_revenue < 6000:
        return "CLTV 중간 가치 기업 고객님(잠재적 이탈 고객층) 입니다. '요금 할인(13%)' 제안 가능합니다."
    elif 4001 <= CLTV < 5000 and 2000 <= total_revenue < 4500:
        return "CLTV 중간 가치 기업 고객님(잠재적 이탈 고객층) 입니다. '요금 할인(10%)' 제안 가능합니다."
    elif 4000 <= CLTV < 6000 and 36 <= tenure_months < 60:
        return "CLTV 중간 가치 개인 고객님(잠재적 이탈 고객층) 입니다. '할인 혜택 or 업그레이드 or 맞춤형' 제안 가능합니다."
    elif 2000 <= CLTV < 4000 and total_revenue >= 6000:
        return "CLTV 낮지만 수익 가치가 높은 기업 고객님 입니다. '요금 할인(15%)' 제안 가능합니다."
    elif 2000 <= CLTV < 4000 and 4000 <= total_revenue < 6000:
        return "CLTV 낮지만 수익이 중간 가치인 기업 고객님 입니다. '요금 할인(10%)' 제안 가능합니다."
    elif CLTV > 4000 and 24<= tenure_months < 36:
        return "CLTV 낮은 저가치 개인 고객님 입니다. '할인 혜택 or 업그레이드 or 맞춤형' 제안 가능합니다."
    # 경우의 수 추가 부분 
    elif CLTV <= 4000 and tenure_months < 24:
        return "CLTV 낮은 저가치 개인 고객님 입니다. '업그레이드 or 맞춤형'제안 가능합니다."
    elif 2000 <= CLTV < 4000 and tenure_months < 24:
        return "CLTV 낮은 저가치 개인 고객님 입니다. '제안할 마케팅 제안이 없습니다."        
    else:
        return "제안할 마케팅 제안이 없습니다."

# def get_cltv_description_by_customer_id(df):
#     try:
#         customer_id = input("고객 번호를 입력하세요: ")  # 사용자로부터 고객 번호를 입력받음
#         customer_data = df[df['Customer ID'] == customer_id]
#         if customer_data.empty:
#             return "고객 번호를 찾을 수 없습니다."
#         CLTV = customer_data['CLTV'].values[0]
#         total_revenue = customer_data['Total Revenue'].values[0]
#         tenure_months = customer_data['Tenure in Months'].values[0]
#         num_dependents = customer_data['Number of Dependents'].values[0]
#         description = get_cltv_description(CLTV, total_revenue, tenure_months, num_dependents)
#         return description
#     except IndexError:
#         return "고객 번호를 찾을 수 없습니다."

# # 예시
# description = get_cltv_description_by_customer_id(df)
# print(description)
# Out:
# 고객 번호를 입력하세요: 1658-BYGOY
# CLTV 낮은 저가치 개인 고객님 입니다. '업그레이드 or 맞춤형'제안 가능합니다.
